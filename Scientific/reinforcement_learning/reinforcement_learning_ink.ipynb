# %% [markdown]
# <div style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<div align=center>
# 			<font face="XB Niloofar" size=30>
# 				<p></p>
# 				<p></p>
# به نام خدا
# 				<p></p>
# 			</font>
# 			<font color=#FF7500>
# دانشگاه صنعتی شریف - دانشکده مهندسی کامپیوتر
#             </font>
# 			<p></p>
# 			<br />
# 			<br />
# پاییز ۱۳۹۷
# 		</div>
# 		<hr/>
# 		<font color=red size=6>
# 			<br />
# 			<div align=center>
#                یادگیری تقویتی
#             </div>
# 		</font>
# 		<br />
# 		<div align=center>
# میلاد آقاجوهری و سیدپارسا میرطاهری
#         </div>
# 		<hr />
# 		<style type="text/css" scoped>
#         p{
#         border: 1px solid #a2a9b1;background-color: #f8f9fa;display: inline-block;
#         };
#         </style>
# 		<div>
# 			<h3>فهرست مطالب</h3>
# 			<ul style="margin-right: 0;">
#                 <li>
# 					<a href="#what">
#                         یادگیری تقویتی چیست و چرا
#                     </a>
# 				</li>
#                 <li>
# 					<a href="#how">
#                     حل یک مثال ساده با اسفاده از یادگیری تقویتی
#                     </a>
# 				</li>
#                 <li>
# 					<a href="#packman">
#                     بازی پک‌من
#                     </a>
# 				</li>
#         </div>
# 	</font>
# </div>

# %% [markdown]
# <p></p>
# <br />
# <div id="what" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#FF7500 size=6>
# یادگیری تقویتی چییست و چرا
#         </font>
#         <p></p>
#         با سلام بر تمام عزیزان شنونده‌ی این داستان
# 	</font>
# </div>

# %%
cd Project3
# Out:
# /home/miladink/University/rl/SAIC19-Content/Scientific/reinforcement_learning/Project3

# %% [markdown]
# <p></p>
# <br />
# <div id="packman" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#FF7500 size=6>
# یاد گرفتن Q-مقدار‌ها
#         </font>
# 		<p></p>
# 		<hr>
#         بنابر آنچه تا اینجا گفتیم و مشاهده کردیم اگر ما
#        Q
#         مقدار‌ها  را داشته باشیم، می‌توانیم به راحتی تصمیم بهینه در یک وضعیت را مشخص کنیم.
#         اما حالا سوال اصلی این است که چطور می‌توانیم
#         Q
#         مقدار‌ها را حساب کنیم؟
#         <p></p>
#         یک الگوریتم بسیار ساده برای این کار این است که از یکی از وضعیت‌ها شروع کنیم و سپس به صورت تصادفی یکی از اعمالی را که در اختیار ماست انتخاب کنیم و آن را انجام دهیم.
#         بگذارید در ابتدا یک اجرا از این الگوریتم را با همدیگر ببینیم:
#         در اجرایی که در زیر مشاهده می‌کنید، دستیار هوشمند ما به صورت رندوم ۲۰ بار در
#         gridworld
#         بازی می‌کند.
#         البته قابل توجه است که متاسفانه تصادفی بازی کردن، چیزی نیست که به آن هوشمندی بگو‌ییم. اما در ادامه خواهید دید که همین  بازی تصادفی هم در نهایت منجر به درک دقیقی از محیط می‌شود:
# 	</font>
# </div>

# %%
# %run gridworld.py -m
# Out:
# ## Disabling Agents in Manual Mode (-m) ##
#
# RUNNING 1 EPISODES
#
# BEGINNING EPISODE: 1

# %% [markdown]
# <p></p>
# <br />
# <div id="packman" style="direction:rtl;line-height:300%;">
# 		<p></p>
# 		<hr>
# <font face="XB Zar" size=5>
# سوالی که در این‌جا مطرح است این است که ما از چنین بازی تصادفی‌ای چه چیزی را می‌توانیم یاد بگیریم؟
# بیایید کمی با هم دیگر فکر کنیم. ما چه چیزی را می‌خواهیم بدانیم؟ ما در هر وضعیت می‌خواهیم بدانیم که اگر یک
# کنش از بین کنش‌هایی که در اختیار داریم را انتخاب کنیم و پس از دریافت جایزه‌ی آن کنش دیگر بهینه عمل کنیم در انتها به چه میزان
# جایزه دست خواهیم یافت. البته دقت دارید که در اینجا، منظور از جایزه امید ریاضی جایزه است.
# در واقع توصیف دقیق‌تر این است که می‌خواهیم بدانیم در صورتی که یک کنش را انجام دهیم و از آن پس بهینه عمل کنیم،
# امید ریاضی جایزه‌ای که به آن دست پیدا خواهیم کرد چه مقداری است.
# اما چه باید بکنیم؟
# بیایید با هم روشی را برای آشنایی با محیط بسازیم. در ابتدا از روش‌های بسیار ابتدایی شروع می‌کنیم تا روش‌های بهتر و بهتری را خلق کنیم.
# <p></p>
#
# <font color=#FF7500 size=6>
# ایده‌ی بدیهی اول: گشت تصادفی
#  </font>
# ما در اینجا شوربختانه هیچ شهودی نسبت به احتمالات یا جایزه‌ها نداریم. بنابراین تنها راه چاره‌ی ما گشت زدن در محیط است.
# یک راه بسیار ساده شاید این باشد که بارها و بارها یک مسیر را طی‌کنیم و مسیر‌های مختلف را امتحان کنیم تا آرام آرام شهودی نسبت به محیط دست پیدا کنیم.
# فرض کنید که اینگونه شروع کنیم. در یک وضعیت قرار بگیرم و به صورت تصادفی به سمت بالا برویم.
# و همینطور تصادفی حرکت کنیم  تا وقتی که
# بازی تمام شود. یا در واقع یک اپیزود از بازی تمام ‌شود. فرض کنید که در این اجرای از بازی ما به جایزه‌ی
# 100
# رسیده باشیم.
# حالا شهود شما در مورد وضعیت اول چیست؟
# اولین چیزی که به ذهن میر‌سد این است که با خود بگوییم اگر به سمت بالا برویم، می‌توانیم 100
# امتیاز جمع کنیم. آیا این شهود درست است؟
# این شهود اشکال‌های زیادی دارد:
# <ul>
# <li>
# ما بهینه عمل نکرده‌ایم. ما صرفا در یک اجرا به سمت بالا، به امتیاز 100 دست یافته‌ایم. این به هیچ وجه دلیلی بر این نیست که در
# حرکت بهینه به سمت بالا ما نتوانیم بیشتر از صد امتیاز بگیریم.
# در واقع ما پس از حرکت به سمت بالا تصادفی عمل کرده‌ایم و برای همین می‌توان گفت که شاید حرکت هوشمندانه‌تری موجود باشد که ما رابه
# جایزه‌ای بیش از 100 برساند.
# (دقت داشته باشید که منظور امید ریاضی جایزه است.)
# </li>
# <li>
# شاید اتفاقا در همین حرکت تصادفی هم بسیار خوش‌شانس بوده‌ایم که امتیاز 100
# را بدست آورده‌ایم.
# شاید در عمل در این محیط اگر در اول به سمت بالا حرکت کنیم و سپس بهینه حرکت کنیم،
# نهایتا به امیدریاضی
# 80 بتوانیم برسیم.
# چگونه می‌خواهیم مطمین شویم که چنین اتفاقی رخ نداده است؟
# </li>
# </ul>
# خبر خوب این است که الگوریتمی وجود دارد که به اما این اطمینان را می‌دهد که تمام
# Q
# مقدار‌ها را به طور دقیق پیدا کند.
# البته منظور من از دقیق این است که این الگوریتم ما به ما اطمینان می‌دهد که در یک محیط مارکوف،
# در صورتی که تا زمان بی‌نهایت اجرا شود مقادیری را به عنوان
# Q
# مقدار‌ها به ما گزارش می‌دهد که به
# Q
# مقدارهای دقیق همگرا هستند.
# به نظر شما چنین الگوریتمی، چگونه عمل می‌کند؟
# بیایید کمی فکر کنیم بالاخره شاید ما هم به عنوان  مهندسان کامپیوتر و کسانی که اندکی از زیبایی‌ها ریاضی چشیده‌اند بتوانیم خودمان فکر کنیم و لذت خلق یک راه‌حل را بچشیم. من هم به عنوان کسی که این الگوریتم را دیده‌ام به شما اطمینان می‌دهم که این الگوریتم از مفاهیم بسیار پیچیده و خاصی استفاده نمی‌کند که شما با آن آشنا نباشید.
# در واقع اگر کمی دقت کنید تمام دانش لازم برای خلق آن تا به اینجا به شما یاد داده شده است و تنها کافی است که بخواهید از آن استفاده کنید تا بتوانید این الگوریتم را خودتان برای خودتان ابداع کنید.
#
# <p></p>
# یکی از کار‌های خوب و مناسب برای کشف راه‌حل‌های یک مساله، این است که در ابتدا توجه کنیم  که آن راه‌حل باید چه خصوصیاتی داشته باشد. منظور این است که خیلی از مواقع ما دقیقا نمی‌توانیم راه‌حل را مشخص کنیم اما می‌توانیم شهودی داشته باشیم که آن راه‌حل باید چه خصوصیاتی داشته باشد؟
#
# <p></p>
# خواهشا در اینجا کمی توقف کنید و کمی فکر کنید. به نظر شما این چنین الگوریتمی چه خصوصیاتی باید داشته باشد؟
# چه شرایطی را اگر رعایت نکند به این معناست که قطعا نمی‌تواند ادعا کند که در صورت اجرا شدن تا بی نهایت در یک محیط مارکوف مقادیری که گزارش می‌کند به
# Q
# مقدار‌های صحیح و درست همگرا شوند؟
# </font>
# </div>

# %% [markdown]
# <p></p>
# <br />
# <div id="packman" style="direction:rtl;line-height:300%;">
# 		<p></p>
# 		<hr>
# <font face="XB Zar" size=5>
# <font color=#FF7500 size=6>
# تلاشی برای دقیق‌تر کردن شرط‌های لازم برای این الگوریتم
#  </font>
# شاید اولین ایده‌ای که به ذهن یک نفر برسد این است که ما باید در هر وضعیت، حتما تمام کنش‌ها را حداقل یکبار امتحان کنیم زیرا ممکن است آن یک کنش جایزه‌ای بسیار بزرگ داشته‌باشد و در واقع با اختلاف بسیار زیاد با بقیه‌ی جوایز موجود در
#     آن محیط مارکوف از آن‌ها جلو باشد. تا وقتی آن را امتحان نکرده‌باشیم نمی‌توانیم نظر دقیقی در مورد آن محیط بدهیم.
#     بیاید فرض کنیم که یک بازی ویدیوی در جلوی ماست:
#     <img src = "./chicken_invaders.jpg">
#     نمی‌دانم که با این بازی آشنایی دارید یا نه! اما در این بازی شما در هر وضعیت می‌توانید یکی از دکمه‌های کیبرد را فشار دهید و یا موس را کلیک راست یا چپ کنید.
#     هدف شما هم این است که مرغ‌هایی را که در فضا می‌خواهند حکومت مرغی تشکیل دهند از
#     بین ببرید.
#    اکثر کسانی که این بازی را انجام می‌دهند تنها با کلید‌های
#     راست و چپ و بالا و پایین اتکا می‌کنند و چند کلیلک موس.
#     از کجا نمی‌دانیم که مثلا با فشردن دکمه‌ی t
#     که به هر حال یکی از کنش ‌های ممکن ما با یک برنامه‌ی کامپیوتری است، تمام مرغ‌ها در آن کشته نمی‌شوند؟
#     این چیزی نیست که تا آن را امتحان نکنیم بدانیم.
#     این موضوعی خیلی مهم است.
#     پس ما به یک شرط بسیار مهم رسیدیم.
#     <b>
#         ما در هر وضعیت باید تمام کنش‌ها را حداقل یکبار بررسی کرده‌ باشیم.
#     </b>
#     <p></p>
#     آیا شرط دیگری هست که به نظر شما حتما لازم باشد که چنین برنامه‌ای داشته باشد؟
#     برای مثال من خودم وقتی به این فکر می‌کنم که آیا می‌شود یک کنش را تعداد متناهی بار آزمایش کرد؟
#     برای مثال فرض کنید که ما دو سکه‌ی شانس داریم و هر بار می‌توانیم یکی از آن‌ها را بیندازیم و اگر سمت شکل دار سکه بیاید، امتیازی را دریافت کنیم و بعد از ده بار بازی تمام شده است.
#  چیزی که دراینجا مهم است این است که احتمال آمدن هیچ کدام از سمت‌ها را نمی‌دانیم.
#     در واقع این سکه‌ها سکه‌های عادلانه نیستند که هر سمت آن‌ها تنها به احتمال نیم بیاید. بلکه مثلا ممکن است سکه‌ی سمت راست به احتمال
#     هشت دهم بیاید یا به احتمال سه دهم بیاید.
#     <div class="row">
#      <div class="column">
#         <img src="fishcoin.png" alt="fishcoin" style="width:20%;float:left;">
#      </div>
#      <div class="column">
#         <img src="leafcoin.jpeg" alt="leafcoin" style="width:20%;float:right;">
#      </div>
#    </div>
#         حال فرض کنید که جایزه‌ی هر بار انداختن هر سکه هم مشخص است و اگر سمت شکل دار سکه بیاید ما یک سکه‌ی طلا دریافت می‌کنیم.
#     به نظر شما اگر تنها به تعداد متناهی بار یکی از سکه‌ها را بیاندازیم می‌توانیم مطمین باشیم که
#     احتمال دقیق را محاسبه کرده‌ایم؟
#     جواب این سوال کمی به دانش ریاضی نیاز دارد اما به هر حال باید بدانیم که اگر بخواهیم احتمال شکل آمدن مثلا سکه‌ی سمت راست را بدانیم باید  آن را نامتناهی بار بیاندازیم تا بتوانیم با تقسیم تعداد بار‌هایی که شکل آمده است بر تعداد بارهایی که عدد آمده است احتمال شکل آمدن را حساب کنیم.
#     در واقع
#     $$\frac{num(picturs)}{num(tries)}$$
#     وقتی به احتمال واقعی همگرا می‌شود که تعداد بار‌های سکه انداختن به بی‌نهایت برسد.
#     پس در واقع می‌توان گفت
#     <b>
#     الگوریتم ذکر شده هر چه باشد باید نامتناهی بار هر کنش را ارزیابی ‌کند.
#     </b>
# </font>
# </div>

# %% [markdown]
# <p></p>
# <br />
# <div id="packman" style="direction:rtl;line-height:300%;">
# 		<p></p>
# 		<hr>
# <font face="XB Zar" size=5>
# <font color=#FF7500 size=6>
# یک الگوریتم ساده: گشت تصادفی به همراه بروزرسانی Q مقدار‌ها
#  </font>
# فرض کنید که ما در یک وضعیت قرار می‌گیریم و سپس در هر مرحله به صورت تصادفی یک کنش را در محیط انجام می‌دهیم تا بازی تمام شود. و این  عمل را نامتناهی بار انجام می‌دهیم.
#     دقت کنید که این الگوریتم هر دو شرط ذکر شده در بالا را دارد. اما سوال اصلی این است: چگونه
#     Q
#     مقدار‌ها را بروزرسانی‌کنیم؟
#     در واقع چگونه با هر بار انتخاب یک کنش و مشاهده‌ی امتیاز‌ها
#     حدس خودمان از
#     Q
#     مقدار ها را بروزرسانی کنیم؟
#     یک ایده‌ی ابتدایی این است.
#    فرض کنید در وضعیت
#     $S$
#     هستیم وکنش
#     $a$
#     را از بین کنش‌های موجود انتخاب می‌کنیم.
#     سپس
#     $R(s,a,s')$
#     را دریاقت می‌کنیم
#    .
#    به نظر شما چگونه می‌توانیم مقدار
#    $Q(s,a)$
#    را بروزرسانی کنیم تا شهود دقیق‌تری از مقدار آن داشته باشیم؟
#    <p></p>
#    یک ایده‌ی ساده این است که:
#    $$Q_{new}(s,a) = R(s,a,s') + Val(s')$$
#    یا به عبارت دیگر
#    $$Q_{new}(s,a) = R(s,a,s') + max_{a'\in A(s)} Q(s', a')$$
#    نه نه! این اصلا چیز ترسناکی نیست و در واقع بسیار هم ساده است. کل حرفی که این عبارت ریاضی می‌زند این است که حالا که این مقدار از جایزه را با انتخاب این کنش دریافت کردم. اگر در
#    وضعیت
#    $s'$
#    هم بهترین انتخاب‌ها را داشته باشم
#    (
#    که در واقع همان قسمت عجیب‌غریب‌نمای
#    عبارت ریاضی بالاست که در واقع
#    بیان می‌کند که کدام کنش در وضعیت
#    $s'$
#    بهترین امیدریاضی را با توجه به حدس‌های ما تا الآن
#    ایفا می‌کند و سپس
#    مقدار آن امید ریاضی را برمی‌گرداند
#   )
#   چه امیدی می‌توانم با حدس‌های الآنم داشته باشم.
#   <p></p>
#   این عبارت، عبارت بسیار خوبی برای بروزرسانی است اما یک جای کار این عبارت می‌لنگد.
#   نظر شما این نحو از بروزرسانی چه مشکلی می‌تواند داشته باشد؟
#   بیایید با همدیگر ببینیم:
#
# </font>
# </div>

# %%
# %%writefile qlearning_update.py
def qlearning_update(self, state, action, nextState, reward):
    estimatedQ = reward + self.computeValueFromQValues(nextState)
    self.qValues[(state,action)] = estimatedQ
# Out:
# Overwriting qlearning_update.py

# %%
# %run gridworld.py -a q -k 30 -m
# Out:
# RUNNING 30 EPISODES
#
# BEGINNING EPISODE: 1
#
# Started in state: (0, 0)
# Took action: north
# Ended in state: (0, 1)
# Got reward: 0.0
#
# Started in state: (0, 1)
# Took action: north
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: north
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: east
# Ended in state: (1, 2)
# Got reward: 0.0
#
# Started in state: (1, 2)
# Took action: east
# Ended in state: (2, 2)
# Got reward: 0.0
#
# Started in state: (2, 2)
# Took action: south
# Ended in state: (2, 1)
# Got reward: 0.0
#
# Started in state: (2, 1)
# Took action: east
# Ended in state: (3, 1)
# Got reward: 0.0
#
# Started in state: (3, 1)
# Took action: exit
# Ended in state: TERMINAL_STATE
# Got reward: -1
#
# EPISODE 1 COMPLETE: RETURN WAS -0.47829690000000014
#
# BEGINNING EPISODE: 2
#
# Started in state: (0, 0)
# Took action: north
# Ended in state: (0, 0)
# Got reward: 0.0
#
# Started in state: (0, 0)
# Took action: north
# Ended in state: (0, 1)
# Got reward: 0.0
#
# Started in state: (0, 1)
# Took action: north
# Ended in state: (0, 1)
# Got reward: 0.0
#
# Started in state: (0, 1)
# Took action: north
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: east
# Ended in state: (1, 2)
# Got reward: 0.0
#
# Started in state: (1, 2)
# Took action: east
# Ended in state: (2, 2)
# Got reward: 0.0
#
# Started in state: (2, 2)
# Took action: south
# Ended in state: (2, 1)
# Got reward: 0.0
#
# Started in state: (2, 1)
# Took action: east
# Ended in state: (2, 0)
# Got reward: 0.0
#
# Started in state: (2, 0)
# Took action: east
# Ended in state: (3, 0)
# Got reward: 0.0
#
# Started in state: (3, 0)
# Took action: east
# Ended in state: (3, 0)
# Got reward: 0.0
#
# Started in state: (3, 0)
# Took action: north
# Ended in state: (3, 0)
# Got reward: 0.0
#
# Started in state: (3, 0)
# Took action: north
# Ended in state: (2, 0)
# Got reward: 0.0
#
# Started in state: (2, 0)
# Took action: north
# Ended in state: (2, 1)
# Got reward: 0.0
#
# Started in state: (2, 1)
# Took action: east
# Ended in state: (3, 1)
# Got reward: 0.0
#
# Started in state: (3, 1)
# Took action: exit
# Ended in state: TERMINAL_STATE
# Got reward: -1
#
# EPISODE 2 COMPLETE: RETURN WAS -0.22876792454961012
#
# BEGINNING EPISODE: 3
#
# Started in state: (0, 0)
# Took action: north
# Ended in state: (1, 0)
# Got reward: 0.0
#
# Started in state: (1, 0)
# Took action: west
# Ended in state: (0, 0)
# Got reward: 0.0
#
# Started in state: (0, 0)
# Took action: north
# Ended in state: (0, 0)
# Got reward: 0.0
#
# Started in state: (0, 0)
# Took action: north
# Ended in state: (0, 1)
# Got reward: 0.0
#
# Started in state: (0, 1)
# Took action: north
# Ended in state: (0, 1)
# Got reward: 0.0
#
# Started in state: (0, 1)
# Took action: north
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: east
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: east
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: east
# Ended in state: (1, 2)
# Got reward: 0.0
#
# Started in state: (1, 2)
# Took action: east
# Ended in state: (2, 2)
# Got reward: 0.0
#
# Started in state: (2, 2)
# Took action: east
# Ended in state: (3, 2)
# Got reward: 0.0
#
# Started in state: (3, 2)
# Took action: exit
# Ended in state: TERMINAL_STATE
# Got reward: 1
#
# EPISODE 3 COMPLETE: RETURN WAS 0.31381059609000017
#
# BEGINNING EPISODE: 4
#
# Started in state: (0, 0)
# Took action: north
# Ended in state: (0, 1)
# Got reward: 0.0
#
# Started in state: (0, 1)
# Took action: north
# Ended in state: (0, 1)
# Got reward: 0.0
#
# Started in state: (0, 1)
# Took action: north
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: east
# Ended in state: (1, 2)
# Got reward: 0.0
#
# Started in state: (1, 2)
# Took action: east
# Ended in state: (1, 2)
# Got reward: 0.0
#
# Started in state: (1, 2)
# Took action: east
# Ended in state: (2, 2)
# Got reward: 0.0
#
# Started in state: (2, 2)
# Took action: east
# Ended in state: (2, 2)
# Got reward: 0.0
#
# Started in state: (2, 2)
# Took action: east
# Ended in state: (2, 2)
# Got reward: 0.0
#
# Started in state: (2, 2)
# Took action: east
# Ended in state: (3, 2)
# Got reward: 0.0
#
# Started in state: (3, 2)
# Took action: exit
# Ended in state: TERMINAL_STATE
# Got reward: 1
#
# EPISODE 4 COMPLETE: RETURN WAS 0.38742048900000015
#
# BEGINNING EPISODE: 5
#
# Started in state: (0, 0)
# Took action: north
# Ended in state: (0, 1)
# Got reward: 0.0
#
# Started in state: (0, 1)
# Took action: north
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: east
# Ended in state: (1, 2)
# Got reward: 0.0
#
# Started in state: (1, 2)
# Took action: east
# Ended in state: (2, 2)
# Got reward: 0.0
#
# Started in state: (2, 2)
# Took action: east
# Ended in state: (3, 2)
# Got reward: 0.0
#
# Started in state: (3, 2)
# Took action: exit
# Ended in state: TERMINAL_STATE
# Got reward: 1
#
# EPISODE 5 COMPLETE: RETURN WAS 0.5904900000000002
#
# BEGINNING EPISODE: 6
#
# Started in state: (0, 0)
# Took action: north
# Ended in state: (0, 1)
# Got reward: 0.0
#
# Started in state: (0, 1)
# Took action: north
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: east
# Ended in state: (1, 2)
# Got reward: 0.0
#
# Started in state: (1, 2)
# Took action: east
# Ended in state: (2, 2)
# Got reward: 0.0
#
# Started in state: (2, 2)
# Took action: east
# Ended in state: (3, 2)
# Got reward: 0.0
#
# Started in state: (3, 2)
# Took action: exit
# Ended in state: TERMINAL_STATE
# Got reward: 1
#
# EPISODE 6 COMPLETE: RETURN WAS 0.5904900000000002
#
# BEGINNING EPISODE: 7
#
# Started in state: (0, 0)
# Took action: north
# Ended in state: (0, 1)
# Got reward: 0.0
#
# Started in state: (0, 1)
# Took action: north
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: east
# Ended in state: (1, 2)
# Got reward: 0.0
#
# Started in state: (1, 2)
# Took action: east
# Ended in state: (1, 2)
# Got reward: 0.0
#
# Started in state: (1, 2)
# Took action: east
# Ended in state: (1, 2)
# Got reward: 0.0
#
# Started in state: (1, 2)
# Took action: east
# Ended in state: (2, 2)
# Got reward: 0.0
#
# Started in state: (2, 2)
# Took action: east
# Ended in state: (3, 2)
# Got reward: 0.0
#
# Started in state: (3, 2)
# Took action: exit
# Ended in state: TERMINAL_STATE
# Got reward: 1
#
# EPISODE 7 COMPLETE: RETURN WAS 0.47829690000000014
#
# BEGINNING EPISODE: 8
#
# Started in state: (0, 0)
# Took action: north
# Ended in state: (0, 0)
# Got reward: 0.0
#
# Started in state: (0, 0)
# Took action: north
# Ended in state: (0, 1)
# Got reward: 0.0
#
# Started in state: (0, 1)
# Took action: north
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: east
# Ended in state: (1, 2)
# Got reward: 0.0
#
# Started in state: (1, 2)
# Took action: east
# Ended in state: (2, 2)
# Got reward: 0.0
#
# Started in state: (2, 2)
# Took action: east
# Ended in state: (3, 2)
# Got reward: 0.0
#
# Started in state: (3, 2)
# Took action: exit
# Ended in state: TERMINAL_STATE
# Got reward: 1
#
# EPISODE 8 COMPLETE: RETURN WAS 0.5314410000000002
#
# BEGINNING EPISODE: 9
#
# Started in state: (0, 0)
# Took action: north
# Ended in state: (0, 1)
# Got reward: 0.0
#
# Started in state: (0, 1)
# Took action: north
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: east
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: east
# Ended in state: (1, 2)
# Got reward: 0.0
#
# Started in state: (1, 2)
# Took action: east
# Ended in state: (2, 2)
# Got reward: 0.0
#
# Started in state: (2, 2)
# Took action: east
# Ended in state: (3, 2)
# Got reward: 0.0
#
# Started in state: (3, 2)
# Took action: exit
# Ended in state: TERMINAL_STATE
# Got reward: 1
#
# EPISODE 9 COMPLETE: RETURN WAS 0.5314410000000002
#
# BEGINNING EPISODE: 10
#
# Started in state: (0, 0)
# Took action: north
# Ended in state: (0, 1)
# Got reward: 0.0
#
# Started in state: (0, 1)
# Took action: north
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: east
# Ended in state: (0, 1)
# Got reward: 0.0
#
# Started in state: (0, 1)
# Took action: east
# Ended in state: (0, 1)
# Got reward: 0.0
#
# Started in state: (0, 1)
# Took action: east
# Ended in state: (0, 1)
# Got reward: 0.0
#
# Started in state: (0, 1)
# Took action: north
# Ended in state: (0, 1)
# Got reward: 0.0
#
# Started in state: (0, 1)
# Took action: east
# Ended in state: (0, 1)
# Got reward: 0.0
#
# Started in state: (0, 1)
# Took action: north
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: east
# Ended in state: (1, 2)
# Got reward: 0.0
#
# Started in state: (1, 2)
# Took action: east
# Ended in state: (2, 2)
# Got reward: 0.0
#
# Started in state: (2, 2)
# Took action: east
# Ended in state: (3, 2)
# Got reward: 0.0
# Started in state: (3, 2)
# Took action: exit
# Ended in state: TERMINAL_STATE
# Got reward: 1
#
# EPISODE 10 COMPLETE: RETURN WAS 0.31381059609000017
#
# BEGINNING EPISODE: 11
#
# Started in state: (0, 0)
# Took action: north
# Ended in state: (1, 0)
# Got reward: 0.0
#
# Started in state: (1, 0)
# Took action: north
# Ended in state: (1, 0)
# Got reward: 0.0
#
# Started in state: (1, 0)
# Took action: west
# Ended in state: (0, 0)
# Got reward: 0.0
#
# Started in state: (0, 0)
# Took action: north
# Ended in state: (0, 1)
# Got reward: 0.0
#
# Started in state: (0, 1)
# Took action: north
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: east
# Ended in state: (1, 2)
# Got reward: 0.0
#
# Started in state: (1, 2)
# Took action: east
# Ended in state: (2, 2)
# Got reward: 0.0
#
# Started in state: (2, 2)
# Took action: east
# Ended in state: (2, 1)
# Got reward: 0.0
#
# Started in state: (2, 1)
# Took action: south
# Ended in state: (2, 0)
# Got reward: 0.0
#
# Started in state: (2, 0)
# Took action: west
# Ended in state: (1, 0)
# Got reward: 0.0
#
# Started in state: (1, 0)
# Took action: west
# Ended in state: (0, 0)
# Got reward: 0.0
#
# Started in state: (0, 0)
# Took action: north
# Ended in state: (0, 1)
# Got reward: 0.0
#
# Started in state: (0, 1)
# Took action: east
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: north
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: east
# Ended in state: (1, 2)
# Got reward: 0.0
#
# Started in state: (1, 2)
# Took action: east
# Ended in state: (2, 2)
# Got reward: 0.0
#
# Started in state: (2, 2)
# Took action: east
# Ended in state: (3, 2)
# Got reward: 0.0
#
# Started in state: (3, 2)
# Took action: exit
# Ended in state: TERMINAL_STATE
# Got reward: 1
#
# EPISODE 11 COMPLETE: RETURN WAS 0.16677181699666577
#
# BEGINNING EPISODE: 12
#
# Started in state: (0, 0)
# Took action: north
# Ended in state: (0, 1)
# Got reward: 0.0
#
# Started in state: (0, 1)
# Took action: north
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: east
# Ended in state: (1, 2)
# Got reward: 0.0
#
# Started in state: (1, 2)
# Took action: east
# Ended in state: (2, 2)
# Got reward: 0.0
#
# Started in state: (2, 2)
# Took action: south
# Ended in state: (2, 1)
# Got reward: 0.0
#
# Started in state: (2, 1)
# Took action: south
# Ended in state: (3, 1)
# Got reward: 0.0
#
# Started in state: (3, 1)
# Took action: exit
# Ended in state: TERMINAL_STATE
# Got reward: -1
#
# EPISODE 12 COMPLETE: RETURN WAS -0.5314410000000002
#
# BEGINNING EPISODE: 13
#
# Started in state: (0, 0)
# Took action: east
# Ended in state: (1, 0)
# Got reward: 0.0
#
# Started in state: (1, 0)
# Took action: east
# Ended in state: (2, 0)
# Got reward: 0.0
#
# Started in state: (2, 0)
# Took action: north
# Ended in state: (2, 1)
# Got reward: 0.0
#
# Started in state: (2, 1)
# Took action: north
# Ended in state: (2, 2)
# Got reward: 0.0
#
# Started in state: (2, 2)
# Took action: west
# Ended in state: (1, 2)
# Got reward: 0.0
#
# Started in state: (1, 2)
# Took action: west
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: west
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: south
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: south
# Ended in state: (0, 1)
# Got reward: 0.0
#
# Started in state: (0, 1)
# Took action: south
# Ended in state: (0, 0)
# Got reward: 0.0
#
# Started in state: (0, 0)
# Took action: south
# Ended in state: (0, 0)
# Got reward: 0.0
#
# Started in state: (0, 0)
# Took action: east
# Ended in state: (0, 0)
# Got reward: 0.0
#
# Started in state: (0, 0)
# Took action: west
# Ended in state: (0, 0)
# Got reward: 0.0
#
# Started in state: (0, 0)
# Took action: east
# Ended in state: (0, 1)
# Got reward: 0.0
#
# Started in state: (0, 1)
# Took action: west
# Ended in state: (0, 1)
# Got reward: 0.0
#
# Started in state: (0, 1)
# Took action: north
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: south
# Ended in state: (0, 1)
# Got reward: 0.0
#
# Started in state: (0, 1)
# Took action: west
# Ended in state: (0, 1)
# Got reward: 0.0
#
# Started in state: (0, 1)
# Took action: north
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: east
# Ended in state: (1, 2)
# Got reward: 0.0
#
# Started in state: (1, 2)
# Took action: north
# Ended in state: (1, 2)
# Got reward: 0.0
#
# Started in state: (1, 2)
# Took action: south
# Ended in state: (1, 2)
# Got reward: 0.0
#
# Started in state: (1, 2)
# Took action: west
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: west
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: west
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: north
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: north
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: north
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: north
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: north
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: north
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: north
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: north
# Ended in state: (1, 2)
# Got reward: 0.0
#
# Started in state: (1, 2)
# Took action: north
# Ended in state: (1, 2)
# Got reward: 0.0
#
# Started in state: (1, 2)
# Took action: north
# Ended in state: (1, 2)
# Got reward: 0.0
#
# Started in state: (1, 2)
# Took action: west
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: north
# Ended in state: (1, 2)
# Got reward: 0.0
#
# Started in state: (1, 2)
# Took action: west
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: north
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: north
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: north
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: north
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: north
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: east
# Ended in state: (1, 2)
# Got reward: 0.0
#
# Started in state: (1, 2)
# Took action: west
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: east
# Ended in state: (0, 1)
# Got reward: 0.0
#
# Started in state: (0, 1)
# Took action: north
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: north
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: north
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: north
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: north
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: north
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: north
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: north
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: north
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: north
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: north
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: north
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: north
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: north
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: north
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: north
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: north
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: north
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: east
# Ended in state: (1, 2)
# Got reward: 0.0
#
# Started in state: (1, 2)
# Took action: west
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: south
# Ended in state: (0, 1)
# Got reward: 0.0
#
# Started in state: (0, 1)
# Took action: south
# Ended in state: (0, 0)
# Got reward: 0.0
#
# Started in state: (0, 0)
# Took action: west
# Ended in state: (0, 0)
# Got reward: 0.0
#
# Started in state: (0, 0)
# Took action: west
# Ended in state: (0, 0)
# Got reward: 0.0
# Started in state: (0, 0)
# Took action: west
# Ended in state: (0, 0)
# Got reward: 0.0
#
# Started in state: (0, 0)
# Took action: west
# Ended in state: (0, 0)
# Got reward: 0.0
#
# Started in state: (0, 0)
# Took action: west
# Ended in state: (0, 0)
# Got reward: 0.0
#
# Started in state: (0, 0)
# Took action: west
# Ended in state: (0, 0)
# Got reward: 0.0
#
# Started in state: (0, 0)
# Took action: west
# Ended in state: (0, 0)
# Got reward: 0.0
#
# Started in state: (0, 0)
# Took action: west
# Ended in state: (0, 0)
# Got reward: 0.0
#
# Started in state: (0, 0)
# Took action: west
# Ended in state: (0, 1)
# Got reward: 0.0
#
# Started in state: (0, 1)
# Took action: west
# Ended in state: (0, 1)
# Got reward: 0.0
#
# Started in state: (0, 1)
# Took action: west
# Ended in state: (0, 1)
# Got reward: 0.0
#
# Started in state: (0, 1)
# Took action: west
# Ended in state: (0, 1)
# Got reward: 0.0
#
# Started in state: (0, 1)
# Took action: west
# Ended in state: (0, 1)
# Got reward: 0.0
#
# Started in state: (0, 1)
# Took action: west
# Ended in state: (0, 1)
# Got reward: 0.0
#
# Started in state: (0, 1)
# Took action: west
# Ended in state: (0, 0)
# Got reward: 0.0
#
# Started in state: (0, 0)
# Took action: west
# Ended in state: (0, 0)
# Got reward: 0.0
#
# Started in state: (0, 0)
# Took action: west
# Ended in state: (0, 0)
# Got reward: 0.0
#
# Started in state: (0, 0)
# Took action: north
# Ended in state: (0, 1)
# Got reward: 0.0
#
# Started in state: (0, 1)
# Took action: north
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: north
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: north
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: north
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: north
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: north
# Ended in state: (1, 2)
# Got reward: 0.0
#
# Started in state: (1, 2)
# Took action: east
# Ended in state: (2, 2)
# Got reward: 0.0
#
# Started in state: (2, 2)
# Took action: west
# Ended in state: (1, 2)
# Got reward: 0.0
#
# Started in state: (1, 2)
# Took action: west
# Ended in state: (1, 2)
# Got reward: 0.0
#
# Started in state: (1, 2)
# Took action: west
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: west
# Ended in state: (0, 1)
# Got reward: 0.0
#
# Started in state: (0, 1)
# Took action: west
# Ended in state: (0, 1)
# Got reward: 0.0
#
# Started in state: (0, 1)
# Took action: east
# Ended in state: (0, 1)
# Got reward: 0.0
#
# Started in state: (0, 1)
# Took action: east
# Ended in state: (0, 1)
# Got reward: 0.0
#
# Started in state: (0, 1)
# Took action: west
# Ended in state: (0, 1)
# Got reward: 0.0
#
# Started in state: (0, 1)
# Took action: east
# Ended in state: (0, 0)
# Got reward: 0.0
#
# Started in state: (0, 0)
# Took action: east
# Ended in state: (0, 1)
# Got reward: 0.0
#
# Started in state: (0, 1)
# Took action: east
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: west
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: west
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: west
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: west
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: north
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: north
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: north
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: north
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: east
# Ended in state: (1, 2)
# Got reward: 0.0
#
# Started in state: (1, 2)
# Took action: east
# Ended in state: (2, 2)
# Got reward: 0.0
#
# Started in state: (2, 2)
# Took action: east
# Ended in state: (3, 2)
# Got reward: 0.0
#
# Started in state: (3, 2)
# Took action: exit
# Ended in state: TERMINAL_STATE
# Got reward: 1
#
# EPISODE 13 COMPLETE: RETURN WAS 5.468756486982954e-06
#
# BEGINNING EPISODE: 14
#
# Started in state: (0, 0)
# Took action: north
# Ended in state: (0, 1)
# Got reward: 0.0
#
# Started in state: (0, 1)
# Took action: north
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: east
# Ended in state: (1, 2)
# Got reward: 0.0
#
# Started in state: (1, 2)
# Took action: east
# Ended in state: (1, 2)
# Got reward: 0.0
#
# Started in state: (1, 2)
# Took action: east
# Ended in state: (1, 2)
# Got reward: 0.0
#
# Started in state: (1, 2)
# Took action: east
# Ended in state: (2, 2)
# Got reward: 0.0
#
# Started in state: (2, 2)
# Took action: east
# Ended in state: (3, 2)
# Got reward: 0.0
#
# Started in state: (3, 2)
# Took action: exit
# Ended in state: TERMINAL_STATE
# Got reward: 1
#
# EPISODE 14 COMPLETE: RETURN WAS 0.47829690000000014
#
# BEGINNING EPISODE: 15
#
# Started in state: (0, 0)
# Took action: north
# Ended in state: (0, 1)
# Got reward: 0.0
#
# Started in state: (0, 1)
# Took action: north
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: north
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: east
# Ended in state: (1, 2)
# Got reward: 0.0
#
# Started in state: (1, 2)
# Took action: east
# Ended in state: (2, 2)
# Got reward: 0.0
#
# Started in state: (2, 2)
# Took action: east
# Ended in state: (2, 2)
# Got reward: 0.0
#
# Started in state: (2, 2)
# Took action: east
# Ended in state: (3, 2)
# Got reward: 0.0
#
# Started in state: (3, 2)
# Took action: exit
# Ended in state: TERMINAL_STATE
# Got reward: 1

# %% [markdown]
# <p></p>
# <br />
# <div id="packman" style="direction:rtl;line-height:300%;">
# 		<p></p>
# 		<hr>
# <font face="XB Zar" size=5>
# متوجه شدن مشکلات این نحوه از بروزرسانی شاید در ابتدا به نظر نرسند اما با کمی بررسی متوجه آن‌ها خواهید شد. خواهش ما این است که ابتدا سعی کنید خودتان مشکلات آن را بیابید و سپس در زیر که لیستی است که به عقل ما رسیده است توجه کنید.
# <p></p>
#     از نظر ما بزرگترین مشکل این نحوه از بروزرسانی توجه به آخرین اتفاق در محیطی است که اتفاقات تصادفی هستند. بگذارید با استفاده از یک مثال ساده موضوع را شرح دهیم. همانطور که قبلا بررسی شده است در بازی
#    gridWorld
#    خانه‌ی سمت راست بالا امتیاز یک دارد. خانه‌ی سمت راست آن را در نظر بگیرید. حرکت به سمت راست در این خانه باید امیدریاضی بالایی داشته باشد.
#     چرا؟
#     چونکه در نزدیکی یک خانه‌ی یک امتیازی است و اگر حرکت به سمت راست موفقیت آمیز باشد ما
#     در نزدیکی کسب یک امتیاز هستیم. اما حالا فرض کنید که موفقیت آمیز نباشد. بدین معنا که همانطور که می‌دانیم هر حرکت در
#     gridworld
#     با یک خطای اندک انجام می‌شود. ما به خانه‌ی پایین می‌رویم و باز هم شانس بازگشت به خانه‌ی بالا را داریم.
#     اما نمونه‌ی زیر را نگاه کنید که در هنگام یادگیری اتفاق افتاده است.
#     در ابتدا وضعیت به صورت زیر بوده است:
#     <img src = "./direct_mistake.png">
#     حال ربات ما در وضعیت بالا تصمیم می‌گیرد به سمت راست برود اما دراینجا به سمت پایین می‌لغزد. همانطور که می‌بینید ناگهان ارزش حرکت به سمت راست در آن خانه برای او به شدت پایین می‌آید.
#     <img src = "./direct_mistake_2.png">
#  اما چنین اتفاقی منطقی نیست زیرا قبل از این اتفاق بار‌ها همین ربات
# از طریق همین حرکت در همین خانه به خانه‌ی یک رفته بود. این کاهش شدید در ارزش منطقی نیست.
#     در واقع به صورت خلاصه مشکل این روش یادگیری
#     <b>
#         تصمیم گرفتن بر اساس آخرین اطلاع و فراموش کردن گذشته در محیطی تصادفی است که اتفاقات تصادفی بسیار می‌افتند و آخرین تجربه می‌تواند نمایانگر بخش کوچکی از احتمالات در آن محیط باشد.
#
#     </b>
# </font>
# </div>

# %% [markdown]
# <p></p>
# <br />
# <div id="packman" style="direction:rtl;line-height:300%;">
# 		<p></p>
# 		<hr>
# <font face="XB Zar" size=5>
# از مشکلات روش بالا گفتیم. اما چه کنیم تا تابعی منطقی‌تر برای بروزرسانی داشته باشیم؟
# دوست عزیز ایده‌ای بزن که به این ره گرفتار گشته‌ایم.
# البته ایده‌ی حل این مساله سخت یا پیچیده نیست. بلکه ایده‌ا‌ی بسیار ساده است.
# کافی است خاطره‌ای را که از قبل در ذهنمان نسبت به
# $Q(s,a)$
# داشتیم به صورت کامل فراموش نکنیم و بلکه آن را در خاطر خودمان داشته باشیم.
# به عبارت جدید بروزرسانی دقت کنید.
# $$Q_{new}(s,a) = \alpha \times [ R(s,a,s') + Val(s') ] + (1-\alpha) \times Q_{old}(s,a) $$
# یا به عبارت دیگر
# $$Q_{new}(s,a) = \alpha \times [ R(s,a,s') + max_{a'\in A(s)} Q(s', a')] + (1-\alpha) \times Q_{old}(s,a)$$
# همانطور که می‌بینید در این جا ما
#     با یک ضریب
#     $\alpha$
#     خاطرات جدیدمان را تاثیر می‌دهیم و با ضریب
#     $1- \alpha$
#     خاطرات گذشته را به یاد می‌آوریم.
#
# </font>
# </div>

# %%
# %%writefile qlearning_update.py
def qlearning_update(self, state, action, nextState, reward):
    self.alpha = 0.9
    estimatedQ = self.alhpa * (reward + self.computeValueFromQValues(nextState)) + (1-self.alpha)*self.qvalues[(state,action)]
    self.qValues[(state,action)] = estimatedQ
# Out:
# Overwriting qlearning_update.py

# %%
# %run gridworld.py -a q -k 30 -m
# Out:
# RUNNING 30 EPISODES
#
# BEGINNING EPISODE: 1
#
# Started in state: (0, 0)
# Took action: north
# Ended in state: (0, 0)
# Got reward: 0.0
#
# Started in state: (0, 0)
# Took action: north
# Ended in state: (0, 1)
# Got reward: 0.0
#
# Started in state: (0, 1)
# Took action: north
# Ended in state: (0, 1)
# Got reward: 0.0
#
# Started in state: (0, 1)
# Took action: north
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: east
# Ended in state: (1, 2)
# Got reward: 0.0
#
# Started in state: (1, 2)
# Took action: east
# Ended in state: (2, 2)
# Got reward: 0.0
#
# Started in state: (2, 2)
# Took action: east
# Ended in state: (3, 2)
# Got reward: 0.0
#
# Started in state: (3, 2)
# Took action: exit
# Ended in state: TERMINAL_STATE
# Got reward: 1
#
# EPISODE 1 COMPLETE: RETURN WAS 0.47829690000000014
#
# BEGINNING EPISODE: 2
#
# Started in state: (0, 0)
# Took action: north
# Ended in state: (1, 0)
# Got reward: 0.0
#
# Started in state: (1, 0)
# Took action: north
# Ended in state: (1, 0)
# Got reward: 0.0
#
# Started in state: (1, 0)
# Took action: west
# Ended in state: (0, 0)
# Got reward: 0.0
#
# Started in state: (0, 0)
# Took action: north
# Ended in state: (1, 0)
# Got reward: 0.0
#
# Started in state: (1, 0)
# Took action: north
# Ended in state: (1, 0)
# Got reward: 0.0
#
# Started in state: (1, 0)
# Took action: west
# Ended in state: (0, 0)
# Got reward: 0.0
#
# Started in state: (0, 0)
# Took action: north
# Ended in state: (1, 0)
# Got reward: 0.0
#
# Started in state: (1, 0)
# Took action: west
# Ended in state: (0, 0)
# Got reward: 0.0
#
# Started in state: (0, 0)
# Took action: north
# Ended in state: (0, 1)
# Got reward: 0.0
#
# Started in state: (0, 1)
# Took action: north
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: north
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: east
# Ended in state: (1, 2)
# Got reward: 0.0
#
# Started in state: (1, 2)
# Took action: east
# Ended in state: (1, 2)
# Got reward: 0.0
#
# Started in state: (1, 2)
# Took action: east
# Ended in state: (2, 2)
# Got reward: 0.0
#
# Started in state: (2, 2)
# Took action: east
# Ended in state: (3, 2)
# Got reward: 0.0
#
# Started in state: (3, 2)
# Took action: exit
# Ended in state: TERMINAL_STATE
# Got reward: 1
#
# EPISODE 2 COMPLETE: RETURN WAS 0.2058911320946491
#
# BEGINNING EPISODE: 3
#
# Started in state: (0, 0)
# Took action: north
# Ended in state: (0, 1)
# Got reward: 0.0
#
# Started in state: (0, 1)
# Took action: north
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: east
# Ended in state: (0, 1)
# Got reward: 0.0
#
# Started in state: (0, 1)
# Took action: east
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: east
# Ended in state: (1, 2)
# Got reward: 0.0
#
# Started in state: (1, 2)
# Took action: east
# Ended in state: (2, 2)
# Got reward: 0.0
#
# Started in state: (2, 2)
# Took action: east
# Ended in state: (3, 2)
# Got reward: 0.0
#
# Started in state: (3, 2)
# Took action: exit
# Ended in state: TERMINAL_STATE
# Got reward: 1
#
# EPISODE 3 COMPLETE: RETURN WAS 0.47829690000000014
#
# BEGINNING EPISODE: 4
#
# Started in state: (0, 0)
# Took action: north
# Ended in state: (0, 1)
# Got reward: 0.0
#
# Started in state: (0, 1)
# Took action: north
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: east
# Ended in state: (1, 2)
# Got reward: 0.0
#
# Started in state: (1, 2)
# Took action: east
# Ended in state: (2, 2)
# Got reward: 0.0
#
# Started in state: (2, 2)
# Took action: east
# Ended in state: (3, 2)
# Got reward: 0.0
#
# Started in state: (3, 2)
# Took action: exit
# Ended in state: TERMINAL_STATE
# Got reward: 1
#
# EPISODE 4 COMPLETE: RETURN WAS 0.5904900000000002
#
# BEGINNING EPISODE: 5
#
# Started in state: (0, 0)
# Took action: north
# Ended in state: (0, 1)
# Got reward: 0.0
#
# Started in state: (0, 1)
# Took action: north
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: east
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: east
# Ended in state: (0, 1)
# Got reward: 0.0
#
# Started in state: (0, 1)
# Took action: east
# Ended in state: (0, 1)
# Got reward: 0.0
#
# Started in state: (0, 1)
# Took action: north
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: east
# Ended in state: (1, 2)
# Got reward: 0.0
#
# Started in state: (1, 2)
# Took action: east
# Ended in state: (2, 2)
# Got reward: 0.0
#
# Started in state: (2, 2)
# Took action: east
# Ended in state: (3, 2)
# Got reward: 0.0
#
# Started in state: (3, 2)
# Took action: exit
# Ended in state: TERMINAL_STATE
# Got reward: 1
#
# EPISODE 5 COMPLETE: RETURN WAS 0.38742048900000015
#
# BEGINNING EPISODE: 6
#
# Started in state: (0, 0)
# Took action: north
# Ended in state: (0, 1)
# Got reward: 0.0
#
# Started in state: (0, 1)
# Took action: north
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: east
# Ended in state: (1, 2)
# Got reward: 0.0
#
# Started in state: (1, 2)
# Took action: east
# Ended in state: (2, 2)
# Got reward: 0.0
#
# Started in state: (2, 2)
# Took action: east
# Ended in state: (3, 2)
# Got reward: 0.0
#
# Started in state: (3, 2)
# Took action: exit
# Ended in state: TERMINAL_STATE
# Got reward: 1
#
# EPISODE 6 COMPLETE: RETURN WAS 0.5904900000000002
#
# BEGINNING EPISODE: 7
#
# Started in state: (0, 0)
# Took action: north
# Ended in state: (0, 1)
# Got reward: 0.0
#
# Started in state: (0, 1)
# Took action: north
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: east
# Ended in state: (0, 1)
# Got reward: 0.0
#
# Started in state: (0, 1)
# Took action: east
# Ended in state: (0, 1)
# Got reward: 0.0
#
# Started in state: (0, 1)
# Took action: north
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: east
# Ended in state: (1, 2)
# Got reward: 0.0
#
# Started in state: (1, 2)
# Took action: east
# Ended in state: (1, 2)
# Got reward: 0.0
#
# Started in state: (1, 2)
# Took action: east
# Ended in state: (2, 2)
# Got reward: 0.0
#
# Started in state: (2, 2)
# Took action: east
# Ended in state: (3, 2)
# Got reward: 0.0
#
# Started in state: (3, 2)
# Took action: exit
# Ended in state: TERMINAL_STATE
# Got reward: 1
#
# EPISODE 7 COMPLETE: RETURN WAS 0.38742048900000015
#
# BEGINNING EPISODE: 8
#
# Started in state: (0, 0)
# Took action: north
# Ended in state: (0, 1)
# Got reward: 0.0
#
# Started in state: (0, 1)
# Took action: north
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: east
# Ended in state: (1, 2)
# Got reward: 0.0
#
# Started in state: (1, 2)
# Took action: east
# Ended in state: (2, 2)
# Got reward: 0.0
#
# Started in state: (2, 2)
# Took action: east
# Ended in state: (3, 2)
# Got reward: 0.0
#
# Started in state: (3, 2)
# Took action: exit
# Ended in state: TERMINAL_STATE
# Got reward: 1
#
# EPISODE 8 COMPLETE: RETURN WAS 0.5904900000000002
#
# BEGINNING EPISODE: 9
#
# Started in state: (0, 0)
# Took action: north
# Ended in state: (0, 1)
# Got reward: 0.0
#
# Started in state: (0, 1)
# Took action: north
# Ended in state: (0, 1)
# Got reward: 0.0
#
# Started in state: (0, 1)
# Took action: east
# Ended in state: (0, 1)
# Got reward: 0.0
#
# Started in state: (0, 1)
# Took action: north
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: east
# Ended in state: (1, 2)
# Got reward: 0.0
#
# Started in state: (1, 2)
# Took action: east
# Ended in state: (1, 2)
# Got reward: 0.0
#
# Started in state: (1, 2)
# Took action: east
# Ended in state: (2, 2)
# Got reward: 0.0
#
# Started in state: (2, 2)
# Took action: east
# Ended in state: (3, 2)
# Got reward: 0.0
#
# Started in state: (3, 2)
# Took action: exit
# Ended in state: TERMINAL_STATE
# Got reward: 1
#
# EPISODE 9 COMPLETE: RETURN WAS 0.43046721000000016
#
# BEGINNING EPISODE: 10
#
# Started in state: (0, 0)
# Took action: north
# Ended in state: (0, 1)
# Got reward: 0.0
#
# Started in state: (0, 1)
# Took action: north
# Ended in state: (0, 1)
# Got reward: 0.0
#
# Started in state: (0, 1)
# Took action: east
# Ended in state: (0, 1)
# Got reward: 0.0
#
# Started in state: (0, 1)
# Took action: north
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: east
# Ended in state: (1, 2)
# Got reward: 0.0
#
# Started in state: (1, 2)
# Took action: east
# Ended in state: (2, 2)
# Got reward: 0.0
#
# Started in state: (2, 2)
# Took action: east
# Ended in state: (3, 2)
# Got reward: 0.0
#
# Started in state: (3, 2)
# Took action: exit
# Ended in state: TERMINAL_STATE
# Got reward: 1
#
# EPISODE 10 COMPLETE: RETURN WAS 0.47829690000000014
#
# BEGINNING EPISODE: 11
#
# Started in state: (0, 0)
# Took action: north
# Ended in state: (0, 1)
# Got reward: 0.0
#
# Started in state: (0, 1)
# Took action: north
# Ended in state: (0, 2)
# Got reward: 0.0
# Started in state: (0, 2)
# Took action: east
# Ended in state: (1, 2)
# Got reward: 0.0
#
# Started in state: (1, 2)
# Took action: east
# Ended in state: (2, 2)
# Got reward: 0.0
#
# Started in state: (2, 2)
# Took action: east
# Ended in state: (3, 2)
# Got reward: 0.0
#
# Started in state: (3, 2)
# Took action: exit
# Ended in state: TERMINAL_STATE
# Got reward: 1
#
# EPISODE 11 COMPLETE: RETURN WAS 0.5904900000000002
#
# BEGINNING EPISODE: 12
#
# Started in state: (0, 0)
# Took action: north
# Ended in state: (0, 1)
# Got reward: 0.0
#
# Started in state: (0, 1)
# Took action: north
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: north
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: east
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: east
# Ended in state: (1, 2)
# Got reward: 0.0
#
# Started in state: (1, 2)
# Took action: east
# Ended in state: (1, 2)
# Got reward: 0.0
#
# Started in state: (1, 2)
# Took action: east
# Ended in state: (2, 2)
# Got reward: 0.0
#
# Started in state: (2, 2)
# Took action: east
# Ended in state: (3, 2)
# Got reward: 0.0
#
# Started in state: (3, 2)
# Took action: exit
# Ended in state: TERMINAL_STATE
# Got reward: 1
#
# EPISODE 12 COMPLETE: RETURN WAS 0.43046721000000016
#
# BEGINNING EPISODE: 13
#
# Started in state: (0, 0)
# Took action: north
# Ended in state: (0, 1)
# Got reward: 0.0
#
# Started in state: (0, 1)
# Took action: north
# Ended in state: (0, 1)
# Got reward: 0.0
#
# Started in state: (0, 1)
# Took action: north
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: east
# Ended in state: (1, 2)
# Got reward: 0.0
#
# Started in state: (1, 2)
# Took action: east
# Ended in state: (2, 2)
# Got reward: 0.0
#
# Started in state: (2, 2)
# Took action: east
# Ended in state: (3, 2)
# Got reward: 0.0
#
# Started in state: (3, 2)
# Took action: exit
# Ended in state: TERMINAL_STATE
# Got reward: 1
#
# EPISODE 13 COMPLETE: RETURN WAS 0.5314410000000002
#
# BEGINNING EPISODE: 14
#
# Started in state: (0, 0)
# Took action: north
# Ended in state: (0, 1)
# Got reward: 0.0
#
# Started in state: (0, 1)
# Took action: north
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: east
# Ended in state: (1, 2)
# Got reward: 0.0
#
# Started in state: (1, 2)
# Took action: east
# Ended in state: (1, 2)
# Got reward: 0.0
#
# Started in state: (1, 2)
# Took action: east
# Ended in state: (2, 2)
# Got reward: 0.0
#
# Started in state: (2, 2)
# Took action: east
# Ended in state: (3, 2)
# Got reward: 0.0
#
# Started in state: (3, 2)
# Took action: exit
# Ended in state: TERMINAL_STATE
# Got reward: 1
#
# EPISODE 14 COMPLETE: RETURN WAS 0.5314410000000002
#
# BEGINNING EPISODE: 15
#
# Started in state: (0, 0)
# Took action: north
# Ended in state: (0, 1)
# Got reward: 0.0
#
# Started in state: (0, 1)
# Took action: north
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: east
# Ended in state: (1, 2)
# Got reward: 0.0
#
# Started in state: (1, 2)
# Took action: east
# Ended in state: (2, 2)
# Got reward: 0.0
#
# Started in state: (2, 2)
# Took action: east
# Ended in state: (3, 2)
# Got reward: 0.0
#
# Started in state: (3, 2)
# Took action: exit
# Ended in state: TERMINAL_STATE
# Got reward: 1
#
# EPISODE 15 COMPLETE: RETURN WAS 0.5904900000000002
#
# BEGINNING EPISODE: 16
#
# Started in state: (0, 0)
# Took action: north
# Ended in state: (0, 1)
# Got reward: 0.0
#
# Started in state: (0, 1)
# Took action: north
# Ended in state: (0, 2)
# Got reward: 0.0
#
# Started in state: (0, 2)
# Took action: east
# Ended in state: (1, 2)
# Got reward: 0.0
#
# Started in state: (1, 2)
# Took action: east
# Ended in state: (2, 2)
# Got reward: 0.0
#
# Started in state: (2, 2)
# Took action: east
# Ended in state: (2, 2)
# Got reward: 0.0
#
# Started in state: (2, 2)
# Took action: east
# Ended in state: (3, 2)
# Got reward: 0.0
#
# Started in state: (3, 2)
# Took action: exit
# Ended in state: TERMINAL_STATE
# Got reward: 1

# %% [markdown]
# <p></p>
# <br/>
# <div id="sec_refs" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#FF7500 size=6>
# منابع
#         </font>
# 		<hr>
#         <ul>
#             <li>
#            کتاب ترکیبیات، علیرضا علیپور، انتشارات فاطمی
#             </li>
#             <li>
# www.briliant.com
#             </li>
#             <li>
# http://www-users.math.umn.edu/~reiner/Classes/Four_Proofs_of_Ballot_Theorem.pdf
#             </li>
#         </ul>
# 	</font>
# </div>

# %%
# %%writefile qlearning_update.py
def qlearning_update(self, state, action, nextState, reward):
    print(self.alpha)
    estimatedQ = reward + self.discount * self.computeValueFromQValues(nextState)
    runningQ = (1-self.alpha) * self.getQValue(state,action) + self.alpha * estimatedQ
    self.qValues[(state,action)] = runningQ
# Out:
# Overwriting qlearning_update.py
